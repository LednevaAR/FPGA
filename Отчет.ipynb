# %% [markdown]
# <a href="https://colab.research.google.com/github/LednevaAR/FPGA/blob/main/%D0%9E%D1%82%D1%87%D0%B5%D1%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Результаты синтеза и симуляции тестового примера из инструкции:

# %% [markdown]
# ![Снимок экрана (2).png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана (3).png](data:image/png;base64,...)

# %% [markdown]
# 2) Результаты синтеза и симуляции модуля мультиплексора 7-to-1 (с использованием SystemVerilog)

# %% [markdown]
# ![Снимок экрана (6).png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана (5).png](data:image/png;base64,...)
